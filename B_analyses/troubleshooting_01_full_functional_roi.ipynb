# %%
# CELL 1: Load CSV and Basic Setup
import pandas as pd
from pathlib import Path
import nibabel as nib
import numpy as np

# Load subject info from CSV
CSV_FILE = Path('/user_data/csimmon2/git_repos/long_pt/long_pt_sub_info.csv')
df = pd.read_csv(CSV_FILE)

BASE_DIR = Path("/user_data/csimmon2/long_pt")
OUTPUT_DIR = BASE_DIR / "analyses" / "rsa_corrected"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Session start mapping (for special cases)
SESSION_START = {'sub-010': 2, 'sub-018': 2, 'sub-068': 2}

# CORRECT CATEGORY_PARCELS
CATEGORY_PARCELS = {
    'face': ['fusiform', 'parahippocampal'],
    'word': ['lateraloccipital', 'inferiortemporal', 'middletemporal'],
    'object': ['lateraloccipital', 'inferiortemporal', 'middletemporal'], 
    'house': ['fusiform', 'parahippocampal', 'lingual', 'isthmuscingulate']
}

# Cope mapping (condition > scramble contrasts)
COPE_MAP = {
    'face': 10, # 10, 11, 12 are the same contrasts as 1, 2, 4
    'word': 12,
    'object': 3,
    'house': 11
}

print("✓ CSV loaded and configuration set")
# Out:
# ✓ CSV loaded and configuration set

# %%
# CELL 2: Paths, Configuration, and Subject Loading Functions
def load_subjects_by_group(group_filter=None, patient_only=True):
    """Fixed version with proper hemisphere mapping"""
    
    filtered_df = df.copy()
    
    if patient_only is True:
        filtered_df = filtered_df[filtered_df['patient'] == 1]
    elif patient_only is False:
        filtered_df = filtered_df[filtered_df['patient'] == 0]
    
    if group_filter:
        if isinstance(group_filter, str):
            group_filter = [group_filter]
        filtered_df = filtered_df[filtered_df['group'].isin(group_filter)]
    
    subjects = {}
    
    for _, row in filtered_df.iterrows():
        subject_id = row['sub']
        
        subj_dir = BASE_DIR / subject_id
        if not subj_dir.exists():
            continue
            
        sessions = []
        for ses_dir in subj_dir.glob('ses-*'):
            if ses_dir.is_dir():
                sessions.append(ses_dir.name.replace('ses-', ''))
        
        if not sessions:
            continue
            
        sessions = sorted(sessions, key=lambda x: int(x))
        start_session = SESSION_START.get(subject_id, 1)
        available_sessions = [s for s in sessions if int(s) >= start_session]
        
        if not available_sessions:
            continue
            
        # FIX: Convert 'left'/'right' to 'l'/'r' to match file naming
        hemisphere_full = row.get('intact_hemi', 'left') if pd.notna(row.get('intact_hemi', None)) else 'left'
        hemisphere = 'l' if hemisphere_full == 'left' else 'r'  # Convert to single letter
        
        subjects[subject_id] = {
            'code': f"{row['group']}{subject_id.split('-')[1]}",
            'sessions': available_sessions,
            'hemi': hemisphere,  # Now uses 'l' or 'r' 
            'group': row['group'],
            'patient_status': 'patient' if row['patient'] == 1 else 'control',
            'age_1': row['age_1'] if pd.notna(row['age_1']) else None
        }
    
    return subjects

# Reload with correct hemisphere mapping
ALL_PATIENTS = load_subjects_by_group(group_filter=None, patient_only=True)
OTC_PATIENTS = load_subjects_by_group(group_filter='OTC', patient_only=True)
NON_OTC_PATIENTS = load_subjects_by_group(group_filter='nonOTC', patient_only=True)
ALL_CONTROLS = load_subjects_by_group(group_filter=None, patient_only=False)
ALL_SUBJECTS = {**ALL_PATIENTS, **ALL_CONTROLS} # Combine patients and controls

# Update analysis subjects
ANALYSIS_SUBJECTS = ALL_SUBJECTS

print("FIXED HEMISPHERE MAPPING:")
for subj_id, info in list(ANALYSIS_SUBJECTS.items())[:3]:
    print(f"  {subj_id}: hemisphere = '{info['hemi']}'")
# Out:
# FIXED HEMISPHERE MAPPING:
#   sub-004: hemisphere = 'l'
#   sub-007: hemisphere = 'r'
#   sub-008: hemisphere = 'l'

# %%
# CELL 3: Resample Individual Parcels to FSL Space
from nilearn.image import resample_to_img

def resample_parcels_to_fsl_space(subject_id):
    """Resample individual parcels from FreeSurfer space to FSL space"""
    
    info = ANALYSIS_SUBJECTS[subject_id]
    code = info['code']
    hemi = info['hemi']
    first_session = info['sessions'][0]
    
    roi_dir = BASE_DIR / subject_id / f'ses-{first_session}' / 'ROIs'
    anat_file = BASE_DIR / subject_id / f'ses-{first_session}' / 'anat' / f'{subject_id}_ses-{first_session}_T1w_brain.nii.gz'
    
    print(f"\n{code} - Resampling parcels to FSL space:")
    print("="*50)
    
    if not anat_file.exists():
        print(f"❌ FSL anatomy not found: {anat_file}")
        return
    
    anat_img = nib.load(anat_file)
    print(f"Target FSL anatomy shape: {anat_img.shape}")
    
    # All parcels that might exist
    parcels = ['fusiform', 'lateraloccipital', 'parahippocampal', 'inferiortemporal', 
               'middletemporal', 'lingual', 'isthmuscingulate']
    
    resampled_count = 0
    
    for parcel in parcels:
        parcel_file = roi_dir / f'{hemi}_{parcel}_mask.nii.gz'
        
        if parcel_file.exists():
            parcel_img = nib.load(parcel_file)
            original_voxels = np.sum(parcel_img.get_fdata() > 0)
            
            if parcel_img.shape != anat_img.shape:
                print(f"  {parcel:20s}: {parcel_img.shape} → {anat_img.shape}")
                
                # Resample to FSL space
                resampled = resample_to_img(parcel_img, anat_img, interpolation='nearest')
                resampled_voxels = np.sum(resampled.get_fdata() > 0)
                
                # Overwrite with resampled version
                nib.save(resampled, parcel_file)
                print(f"    Voxels: {original_voxels:,} → {resampled_voxels:,}")
                resampled_count += 1
            else:
                print(f"  {parcel:20s}: Already correct shape ✓")
        else:
            print(f"  {parcel:20s}: Not found")
    
    print(f"\n✓ Resampled {resampled_count} parcels for {code}")

# Fix alignment for all subjects FIRST
print("\n" + "="*70)
print("STEP 1: RESAMPLING INDIVIDUAL PARCELS TO FSL SPACE")
print("="*70)

for subject_id in ANALYSIS_SUBJECTS.keys():
    resample_parcels_to_fsl_space(subject_id)

print("\n✅ All parcels aligned to FSL space!")
# Out:
# ======================================================================
# STEP 1: RESAMPLING INDIVIDUAL PARCELS TO FSL SPACE
# ======================================================================
#
# OTC004 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC004
#
# nonOTC007 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC007
#
# OTC008 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC008
#
# OTC010 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC010
#
# OTC017 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC017
#
# OTC021 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC021
#
# nonOTC045 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC045
#
# nonOTC047 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC047
#
# nonOTC049 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC049
#
# nonOTC070 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC070
#
# nonOTC072 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC072
#
# nonOTC073 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC073
#
# OTC079 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for OTC079
#
# nonOTC081 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC081
#
# nonOTC086 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for nonOTC086
#
# OTC108 - Resampling parcels to FSL space:
# ==================================================
# ❌ FSL anatomy not found: /user_data/csimmon2/long_pt/sub-108/ses-01/anat/sub-108_ses-01_T1w_brain.nii.gz
#
# control018 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control018
#
# control022 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control022
#
# control025 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control025
#
# control027 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control027
#
# control052 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control052
#
# control058 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control058
#
# control062 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control062
#
# control064 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control064
#
# control068 - Resampling parcels to FSL space:
# ==================================================
# Target FSL anatomy shape: (176, 256, 256)
#   fusiform            : Already correct shape ✓
#   lateraloccipital    : Already correct shape ✓
#   parahippocampal     : Already correct shape ✓
#   inferiortemporal    : Already correct shape ✓
#   middletemporal      : Already correct shape ✓
#   lingual             : Already correct shape ✓
#   isthmuscingulate    : Already correct shape ✓
#
# ✓ Resampled 0 parcels for control068
#
# ✅ All parcels aligned to FSL space!

# %%
# CELL 4: Category-Specific Mask Creation (From Aligned Parcels)
from scipy.ndimage import binary_dilation

def create_category_specific_masks(subject_id, subjects_dict, dilation_iterations=1):
    """
    Create separate anatomical search masks for each category
    Updated to use dynamic subjects dictionary
    """
    if subject_id not in subjects_dict:
        print(f"❌ {subject_id} not in analysis group")
        return {}
        
    info = subjects_dict[subject_id]
    code = info['code']
    hemi = info['hemi']
    first_session = info['sessions'][0]
    
    roi_dir = BASE_DIR / subject_id / f'ses-{first_session}' / 'ROIs'
    
    print(f"\n{'='*70}")
    print(f"{code} - Category-Specific Masks (1x dilation) [ses-{first_session}] [{info['group']} {info['patient_status']}]")
    print(f"{'='*70}")
    
    category_masks = {}
    
    for category, parcel_list in CATEGORY_PARCELS.items():
        print(f"\n{category.upper()}:")
        
        combined = None
        ref_img = None
        
        for parcel in parcel_list:
            parcel_file = roi_dir / f'{hemi}_{parcel}_mask.nii.gz'
            
            if not parcel_file.exists():
                print(f"  ⚠️  Missing: {parcel}")
                continue
            
            img = nib.load(parcel_file)
            mask = img.get_fdata() > 0
            n_vox = np.sum(mask)
            print(f"  {parcel:20s}: {n_vox:6d} voxels")
            
            if combined is None:
                combined = mask
                ref_img = img
            else:
                combined = combined | mask
        
        if combined is None:
            print(f"  ❌ No parcels found")
            continue
        
        print(f"  Combined (before dilation): {np.sum(combined):6d} voxels")
        
        # Single dilation
        combined = binary_dilation(combined, iterations=dilation_iterations)
        print(f"  After 1x dilation:          {np.sum(combined):6d} voxels")
        
        # Save to first session directory
        output_file = roi_dir / f'{hemi}_{category}_searchmask.nii.gz'
        mask_img = nib.Nifti1Image(combined.astype(np.float32), ref_img.affine)
        nib.save(mask_img, output_file)
        
        category_masks[category] = output_file
        print(f"  ✓ Saved: {output_file.name}")
    
    return category_masks

# Create category masks from properly aligned parcels
print("\n" + "="*70)
print(f"STEP 2: CREATING CATEGORY MASKS FROM ALIGNED PARCELS")
print("="*70)

category_masks = {}
for subject_id in ANALYSIS_SUBJECTS.keys():
    category_masks[subject_id] = create_category_specific_masks(subject_id, ANALYSIS_SUBJECTS, dilation_iterations=1)

print(f"\n✅ Category masks created for {len(category_masks)} subjects using properly aligned parcels")
# Out:
# ======================================================================
# STEP 2: CREATING CATEGORY MASKS FROM ALIGNED PARCELS
# ======================================================================
#
# ======================================================================
# OTC004 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  12134 voxels
#   parahippocampal     :   1847 voxels
#   Combined (before dilation):  13981 voxels
#   After 1x dilation:           22163 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15770 voxels
#   inferiortemporal    :  14609 voxels
#   middletemporal      :  15030 voxels
#   Combined (before dilation):  45409 voxels
#   After 1x dilation:           68404 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15770 voxels
#   inferiortemporal    :  14609 voxels
#   middletemporal      :  15030 voxels
#   Combined (before dilation):  45409 voxels
#   After 1x dilation:           68404 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  12134 voxels
#   parahippocampal     :   1847 voxels
#   lingual             :   9576 voxels
#   isthmuscingulate    :   3317 voxels
#   Combined (before dilation):  26874 voxels
#   After 1x dilation:           42590 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC007 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  13276 voxels
#   parahippocampal     :   2085 voxels
#   Combined (before dilation):  15361 voxels
#   After 1x dilation:           24375 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15665 voxels
#   inferiortemporal    :  15602 voxels
#   middletemporal      :  16932 voxels
#   Combined (before dilation):  48199 voxels
#   After 1x dilation:           73616 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15665 voxels
#   inferiortemporal    :  15602 voxels
#   middletemporal      :  16932 voxels
#   Combined (before dilation):  48199 voxels
#   After 1x dilation:           73616 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  13276 voxels
#   parahippocampal     :   2085 voxels
#   lingual             :   8524 voxels
#   isthmuscingulate    :   3192 voxels
#   Combined (before dilation):  27077 voxels
#   After 1x dilation:           44226 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# OTC008 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  10471 voxels
#   parahippocampal     :   2580 voxels
#   Combined (before dilation):  13051 voxels
#   After 1x dilation:           21281 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  10514 voxels
#   inferiortemporal    :  12007 voxels
#   middletemporal      :  12723 voxels
#   Combined (before dilation):  35244 voxels
#   After 1x dilation:           57279 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  10514 voxels
#   inferiortemporal    :  12007 voxels
#   middletemporal      :  12723 voxels
#   Combined (before dilation):  35244 voxels
#   After 1x dilation:           57279 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  10471 voxels
#   parahippocampal     :   2580 voxels
#   lingual             :   5625 voxels
#   isthmuscingulate    :   3427 voxels
#   Combined (before dilation):  22103 voxels
#   After 1x dilation:           36609 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# OTC010 - Category-Specific Masks (1x dilation) [ses-02] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :   5314 voxels
#   parahippocampal     :   1290 voxels
#   Combined (before dilation):   6604 voxels
#   After 1x dilation:           12937 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  11952 voxels
#   inferiortemporal    :   9131 voxels
#   middletemporal      :   9585 voxels
#   Combined (before dilation):  30668 voxels
#   After 1x dilation:           48599 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  11952 voxels
#   inferiortemporal    :   9131 voxels
#   middletemporal      :   9585 voxels
#   Combined (before dilation):  30668 voxels
#   After 1x dilation:           48599 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   5314 voxels
#   parahippocampal     :   1290 voxels
#   lingual             :   4686 voxels
#   isthmuscingulate    :   1865 voxels
#   Combined (before dilation):  13155 voxels
#   After 1x dilation:           25393 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# OTC017 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  11867 voxels
#   parahippocampal     :   1929 voxels
#   Combined (before dilation):  13796 voxels
#   After 1x dilation:           22697 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  14265 voxels
#   inferiortemporal    :  18093 voxels
#   middletemporal      :  19343 voxels
#   Combined (before dilation):  51701 voxels
#   After 1x dilation:           79097 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  14265 voxels
#   inferiortemporal    :  18093 voxels
#   middletemporal      :  19343 voxels
#   Combined (before dilation):  51701 voxels
#   After 1x dilation:           79097 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  11867 voxels
#   parahippocampal     :   1929 voxels
#   lingual             :   6957 voxels
#   isthmuscingulate    :   2383 voxels
#   Combined (before dilation):  23136 voxels
#   After 1x dilation:           38719 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# OTC021 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :   8484 voxels
#   parahippocampal     :   1628 voxels
#   Combined (before dilation):  10112 voxels
#   After 1x dilation:           16217 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  13464 voxels
#   inferiortemporal    :  11072 voxels
#   middletemporal      :  12461 voxels
#   Combined (before dilation):  36997 voxels
#   After 1x dilation:           55679 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  13464 voxels
#   inferiortemporal    :  11072 voxels
#   middletemporal      :  12461 voxels
#   Combined (before dilation):  36997 voxels
#   After 1x dilation:           55679 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   8484 voxels
#   parahippocampal     :   1628 voxels
#   lingual             :   6421 voxels
#   isthmuscingulate    :   1831 voxels
#   Combined (before dilation):  18364 voxels
#   After 1x dilation:           30002 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC045 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  10726 voxels
#   parahippocampal     :   1832 voxels
#   Combined (before dilation):  12558 voxels
#   After 1x dilation:           20131 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  14582 voxels
#   inferiortemporal    :  11748 voxels
#   middletemporal      :  13420 voxels
#   Combined (before dilation):  39750 voxels
#   After 1x dilation:           62199 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  14582 voxels
#   inferiortemporal    :  11748 voxels
#   middletemporal      :  13420 voxels
#   Combined (before dilation):  39750 voxels
#   After 1x dilation:           62199 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  10726 voxels
#   parahippocampal     :   1832 voxels
#   lingual             :   7300 voxels
#   isthmuscingulate    :   2900 voxels
#   Combined (before dilation):  22758 voxels
#   After 1x dilation:           37450 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC047 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  10385 voxels
#   parahippocampal     :   2007 voxels
#   Combined (before dilation):  12392 voxels
#   After 1x dilation:           19349 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15078 voxels
#   inferiortemporal    :  15753 voxels
#   middletemporal      :  14639 voxels
#   Combined (before dilation):  45470 voxels
#   After 1x dilation:           68479 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15078 voxels
#   inferiortemporal    :  15753 voxels
#   middletemporal      :  14639 voxels
#   Combined (before dilation):  45470 voxels
#   After 1x dilation:           68479 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  10385 voxels
#   parahippocampal     :   2007 voxels
#   lingual             :   8296 voxels
#   isthmuscingulate    :   2555 voxels
#   Combined (before dilation):  23243 voxels
#   After 1x dilation:           37594 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC049 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  11645 voxels
#   parahippocampal     :   1784 voxels
#   Combined (before dilation):  13429 voxels
#   After 1x dilation:           21650 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  14036 voxels
#   inferiortemporal    :  10622 voxels
#   middletemporal      :  12214 voxels
#   Combined (before dilation):  36872 voxels
#   After 1x dilation:           58423 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  14036 voxels
#   inferiortemporal    :  10622 voxels
#   middletemporal      :  12214 voxels
#   Combined (before dilation):  36872 voxels
#   After 1x dilation:           58423 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  11645 voxels
#   parahippocampal     :   1784 voxels
#   lingual             :  10216 voxels
#   isthmuscingulate    :   2464 voxels
#   Combined (before dilation):  26109 voxels
#   After 1x dilation:           42527 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC070 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  10388 voxels
#   parahippocampal     :   1915 voxels
#   Combined (before dilation):  12303 voxels
#   After 1x dilation:           20063 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  14599 voxels
#   inferiortemporal    :  13582 voxels
#   middletemporal      :  13012 voxels
#   Combined (before dilation):  41193 voxels
#   After 1x dilation:           64604 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  14599 voxels
#   inferiortemporal    :  13582 voxels
#   middletemporal      :  13012 voxels
#   Combined (before dilation):  41193 voxels
#   After 1x dilation:           64604 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  10388 voxels
#   parahippocampal     :   1915 voxels
#   lingual             :   7306 voxels
#   isthmuscingulate    :   2740 voxels
#   Combined (before dilation):  22349 voxels
#   After 1x dilation:           37597 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC072 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  13657 voxels
#   parahippocampal     :   2245 voxels
#   Combined (before dilation):  15902 voxels
#   After 1x dilation:           25353 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  12252 voxels
#   inferiortemporal    :  12253 voxels
#   middletemporal      :  13025 voxels
#   Combined (before dilation):  37530 voxels
#   After 1x dilation:           60112 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  12252 voxels
#   inferiortemporal    :  12253 voxels
#   middletemporal      :  13025 voxels
#   Combined (before dilation):  37530 voxels
#   After 1x dilation:           60112 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  13657 voxels
#   parahippocampal     :   2245 voxels
#   lingual             :   7333 voxels
#   isthmuscingulate    :   2643 voxels
#   Combined (before dilation):  25878 voxels
#   After 1x dilation:           42108 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC073 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  12261 voxels
#   parahippocampal     :   2364 voxels
#   Combined (before dilation):  14625 voxels
#   After 1x dilation:           23011 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  16799 voxels
#   inferiortemporal    :  13455 voxels
#   middletemporal      :  17346 voxels
#   Combined (before dilation):  47600 voxels
#   After 1x dilation:           72924 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  16799 voxels
#   inferiortemporal    :  13455 voxels
#   middletemporal      :  17346 voxels
#   Combined (before dilation):  47600 voxels
#   After 1x dilation:           72924 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  12261 voxels
#   parahippocampal     :   2364 voxels
#   lingual             :  10261 voxels
#   isthmuscingulate    :   4557 voxels
#   Combined (before dilation):  29443 voxels
#   After 1x dilation:           47079 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# OTC079 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :  12820 voxels
#   parahippocampal     :   2657 voxels
#   Combined (before dilation):  15477 voxels
#   After 1x dilation:           24894 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  16495 voxels
#   inferiortemporal    :  14934 voxels
#   middletemporal      :  15024 voxels
#   Combined (before dilation):  46453 voxels
#   After 1x dilation:           72486 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  16495 voxels
#   inferiortemporal    :  14934 voxels
#   middletemporal      :  15024 voxels
#   Combined (before dilation):  46453 voxels
#   After 1x dilation:           72486 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  12820 voxels
#   parahippocampal     :   2657 voxels
#   lingual             :   5384 voxels
#   isthmuscingulate    :   2857 voxels
#   Combined (before dilation):  23718 voxels
#   After 1x dilation:           39882 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC081 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :   8681 voxels
#   parahippocampal     :   1873 voxels
#   Combined (before dilation):  10554 voxels
#   After 1x dilation:           17146 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  10360 voxels
#   inferiortemporal    :  10436 voxels
#   middletemporal      :  11682 voxels
#   Combined (before dilation):  32478 voxels
#   After 1x dilation:           51056 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  10360 voxels
#   inferiortemporal    :  10436 voxels
#   middletemporal      :  11682 voxels
#   Combined (before dilation):  32478 voxels
#   After 1x dilation:           51056 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   8681 voxels
#   parahippocampal     :   1873 voxels
#   lingual             :   5966 voxels
#   isthmuscingulate    :   2294 voxels
#   Combined (before dilation):  18814 voxels
#   After 1x dilation:           31461 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# nonOTC086 - Category-Specific Masks (1x dilation) [ses-01] [nonOTC patient]
# ======================================================================
#
# FACE:
#   fusiform            :   9129 voxels
#   parahippocampal     :   2699 voxels
#   Combined (before dilation):  11828 voxels
#   After 1x dilation:           19454 voxels
#   ✓ Saved: l_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  12963 voxels
#   inferiortemporal    :  10515 voxels
#   middletemporal      :  10445 voxels
#   Combined (before dilation):  33923 voxels
#   After 1x dilation:           54060 voxels
#   ✓ Saved: l_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  12963 voxels
#   inferiortemporal    :  10515 voxels
#   middletemporal      :  10445 voxels
#   Combined (before dilation):  33923 voxels
#   After 1x dilation:           54060 voxels
#   ✓ Saved: l_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   9129 voxels
#   parahippocampal     :   2699 voxels
#   lingual             :   6429 voxels
#   isthmuscingulate    :   2187 voxels
#   Combined (before dilation):  20444 voxels
#   After 1x dilation:           34032 voxels
#   ✓ Saved: l_house_searchmask.nii.gz
#
# ======================================================================
# OTC108 - Category-Specific Masks (1x dilation) [ses-01] [OTC patient]
# ======================================================================
#
# FACE:
#   ⚠️  Missing: fusiform
#   ⚠️  Missing: parahippocampal
#   ❌ No parcels found
#
# WORD:
#   ⚠️  Missing: lateraloccipital
#   ⚠️  Missing: inferiortemporal
#   ⚠️  Missing: middletemporal
#   ❌ No parcels found
#
# OBJECT:
#   ⚠️  Missing: lateraloccipital
#   ⚠️  Missing: inferiortemporal
#   ⚠️  Missing: middletemporal
#   ❌ No parcels found
#
# HOUSE:
#   ⚠️  Missing: fusiform
#   ⚠️  Missing: parahippocampal
#   ⚠️  Missing: lingual
#   ⚠️  Missing: isthmuscingulate
#   ❌ No parcels found
#
# ======================================================================
# control018 - Category-Specific Masks (1x dilation) [ses-02] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :   9134 voxels
#   parahippocampal     :   2067 voxels
#   Combined (before dilation):  11201 voxels
#   After 1x dilation:           18283 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  12508 voxels
#   inferiortemporal    :  12908 voxels
#   middletemporal      :  14949 voxels
#   Combined (before dilation):  40365 voxels
#   After 1x dilation:           61718 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  12508 voxels
#   inferiortemporal    :  12908 voxels
#   middletemporal      :  14949 voxels
#   Combined (before dilation):  40365 voxels
#   After 1x dilation:           61718 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   9134 voxels
#   parahippocampal     :   2067 voxels
#   lingual             :   7597 voxels
#   isthmuscingulate    :   2923 voxels
#   Combined (before dilation):  21721 voxels
#   After 1x dilation:           35696 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control022 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  12002 voxels
#   parahippocampal     :   2028 voxels
#   Combined (before dilation):  14030 voxels
#   After 1x dilation:           22305 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15438 voxels
#   inferiortemporal    :  17172 voxels
#   middletemporal      :  15094 voxels
#   Combined (before dilation):  47704 voxels
#   After 1x dilation:           72708 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15438 voxels
#   inferiortemporal    :  17172 voxels
#   middletemporal      :  15094 voxels
#   Combined (before dilation):  47704 voxels
#   After 1x dilation:           72708 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  12002 voxels
#   parahippocampal     :   2028 voxels
#   lingual             :   7606 voxels
#   isthmuscingulate    :   3073 voxels
#   Combined (before dilation):  24709 voxels
#   After 1x dilation:           39935 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control025 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  14549 voxels
#   parahippocampal     :   2324 voxels
#   Combined (before dilation):  16873 voxels
#   After 1x dilation:           26579 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  17792 voxels
#   inferiortemporal    :  17005 voxels
#   middletemporal      :  18492 voxels
#   Combined (before dilation):  53289 voxels
#   After 1x dilation:           80862 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  17792 voxels
#   inferiortemporal    :  17005 voxels
#   middletemporal      :  18492 voxels
#   Combined (before dilation):  53289 voxels
#   After 1x dilation:           80862 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  14549 voxels
#   parahippocampal     :   2324 voxels
#   lingual             :  10552 voxels
#   isthmuscingulate    :   3766 voxels
#   Combined (before dilation):  31191 voxels
#   After 1x dilation:           49871 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control027 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :   8515 voxels
#   parahippocampal     :   1633 voxels
#   Combined (before dilation):  10148 voxels
#   After 1x dilation:           16165 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  18086 voxels
#   inferiortemporal    :  11141 voxels
#   middletemporal      :  14978 voxels
#   Combined (before dilation):  44205 voxels
#   After 1x dilation:           65602 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  18086 voxels
#   inferiortemporal    :  11141 voxels
#   middletemporal      :  14978 voxels
#   Combined (before dilation):  44205 voxels
#   After 1x dilation:           65602 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   8515 voxels
#   parahippocampal     :   1633 voxels
#   lingual             :   9422 voxels
#   isthmuscingulate    :   2990 voxels
#   Combined (before dilation):  22560 voxels
#   After 1x dilation:           35848 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control052 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  14678 voxels
#   parahippocampal     :   2078 voxels
#   Combined (before dilation):  16756 voxels
#   After 1x dilation:           26797 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  18330 voxels
#   inferiortemporal    :  15582 voxels
#   middletemporal      :  15958 voxels
#   Combined (before dilation):  49870 voxels
#   After 1x dilation:           76884 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  18330 voxels
#   inferiortemporal    :  15582 voxels
#   middletemporal      :  15958 voxels
#   Combined (before dilation):  49870 voxels
#   After 1x dilation:           76884 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  14678 voxels
#   parahippocampal     :   2078 voxels
#   lingual             :  10109 voxels
#   isthmuscingulate    :   3036 voxels
#   Combined (before dilation):  29901 voxels
#   After 1x dilation:           48765 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control058 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  11156 voxels
#   parahippocampal     :   2327 voxels
#   Combined (before dilation):  13483 voxels
#   After 1x dilation:           21199 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  14128 voxels
#   inferiortemporal    :  11994 voxels
#   middletemporal      :  15703 voxels
#   Combined (before dilation):  41825 voxels
#   After 1x dilation:           63644 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  14128 voxels
#   inferiortemporal    :  11994 voxels
#   middletemporal      :  15703 voxels
#   Combined (before dilation):  41825 voxels
#   After 1x dilation:           63644 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  11156 voxels
#   parahippocampal     :   2327 voxels
#   lingual             :   7273 voxels
#   isthmuscingulate    :   2787 voxels
#   Combined (before dilation):  23543 voxels
#   After 1x dilation:           37693 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control062 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :   8535 voxels
#   parahippocampal     :   2229 voxels
#   Combined (before dilation):  10764 voxels
#   After 1x dilation:           17497 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  10686 voxels
#   inferiortemporal    :  10262 voxels
#   middletemporal      :  12815 voxels
#   Combined (before dilation):  33763 voxels
#   After 1x dilation:           53097 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  10686 voxels
#   inferiortemporal    :  10262 voxels
#   middletemporal      :  12815 voxels
#   Combined (before dilation):  33763 voxels
#   After 1x dilation:           53097 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :   8535 voxels
#   parahippocampal     :   2229 voxels
#   lingual             :   6848 voxels
#   isthmuscingulate    :   2426 voxels
#   Combined (before dilation):  20038 voxels
#   After 1x dilation:           33386 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control064 - Category-Specific Masks (1x dilation) [ses-01] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  10044 voxels
#   parahippocampal     :   2146 voxels
#   Combined (before dilation):  12190 voxels
#   After 1x dilation:           19075 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15353 voxels
#   inferiortemporal    :  14848 voxels
#   middletemporal      :  15969 voxels
#   Combined (before dilation):  46170 voxels
#   After 1x dilation:           69285 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15353 voxels
#   inferiortemporal    :  14848 voxels
#   middletemporal      :  15969 voxels
#   Combined (before dilation):  46170 voxels
#   After 1x dilation:           69285 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  10044 voxels
#   parahippocampal     :   2146 voxels
#   lingual             :   9969 voxels
#   isthmuscingulate    :   3088 voxels
#   Combined (before dilation):  25247 voxels
#   After 1x dilation:           40334 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ======================================================================
# control068 - Category-Specific Masks (1x dilation) [ses-02] [control control]
# ======================================================================
#
# FACE:
#   fusiform            :  12999 voxels
#   parahippocampal     :   2170 voxels
#   Combined (before dilation):  15169 voxels
#   After 1x dilation:           23971 voxels
#   ✓ Saved: r_face_searchmask.nii.gz
#
# WORD:
#   lateraloccipital    :  15841 voxels
#   inferiortemporal    :  13459 voxels
#   middletemporal      :  14087 voxels
#   Combined (before dilation):  43387 voxels
#   After 1x dilation:           67011 voxels
#   ✓ Saved: r_word_searchmask.nii.gz
#
# OBJECT:
#   lateraloccipital    :  15841 voxels
#   inferiortemporal    :  13459 voxels
#   middletemporal      :  14087 voxels
#   Combined (before dilation):  43387 voxels
#   After 1x dilation:           67011 voxels
#   ✓ Saved: r_object_searchmask.nii.gz
#
# HOUSE:
#   fusiform            :  12999 voxels
#   parahippocampal     :   2170 voxels
#   lingual             :   8448 voxels
#   isthmuscingulate    :   3056 voxels
#   Combined (before dilation):  26673 voxels
#   After 1x dilation:           43074 voxels
#   ✓ Saved: r_house_searchmask.nii.gz
#
# ✅ Category masks created for 25 subjects using properly aligned parcels

# %%
# CELL 5: Functional ROI Extraction (Updated and Cleaned)
from scipy.ndimage import label, center_of_mass

def extract_functional_rois_final(subject_id, threshold_z=2.3):
    """
    Extract functional cluster ROIs across all sessions
    Uses category-specific anatomical masks (now properly resampled to FSL space)
    """
    
    # Get subject info from ANALYSIS_SUBJECTS
    info = ANALYSIS_SUBJECTS[subject_id]
    code = info['code']
    hemi = info['hemi']
    sessions = info['sessions']
    first_session = sessions[0]
    
    print(f"\n{'='*70}")
    print(f"{code} - Functional Clusters [masks from ses-{first_session}, z>{threshold_z}] [{info['group']} {info['patient_status']}]")
    print(f"{'='*70}")
    
    all_results = {}
    
    # Process each category using COPE_MAP
    for category, cope_num in COPE_MAP.items():
        print(f"\n{category.upper()}:")
        all_results[category] = {}
        
        # Load category-specific mask (now in correct FSL space)
        mask_file = BASE_DIR / subject_id / f'ses-{first_session}' / 'ROIs' / f'{hemi}_{category}_searchmask.nii.gz'
        if not mask_file.exists():
            print(f"  ⚠️  Mask not found: {mask_file}")
            continue
        
        mask = nib.load(mask_file).get_fdata() > 0
        affine = nib.load(mask_file).affine
        
        # Process each session
        for session in sessions:
            feat_dir = BASE_DIR / subject_id / f'ses-{session}' / 'derivatives' / 'fsl' / 'loc' / 'HighLevel.gfeat'
            
            # Select correct zstat file (first session vs registered to first session)
            zstat_file = 'zstat1.nii.gz' if session == first_session else f'zstat1_ses{first_session}.nii.gz'
            cope_file = feat_dir / f'cope{cope_num}.feat' / 'stats' / zstat_file
            
            if not cope_file.exists():
                print(f"  ses-{session}: cope file missing ({zstat_file})")
                continue
            
            # Load functional activation
            zstat = nib.load(cope_file).get_fdata()
            
            # Apply threshold and mask (should now have matching dimensions)
            suprathresh = (zstat > threshold_z) & mask
            
            if suprathresh.sum() < 50:
                print(f"  ses-{session}: <50 voxels (skipped)")
                continue
            
            # Find connected components
            labeled, n_clusters = label(suprathresh)
            if n_clusters == 0:
                print(f"  ses-{session}: No clusters found")
                continue
            
            # Get largest cluster
            cluster_sizes = [(labeled == i).sum() for i in range(1, n_clusters + 1)]
            largest_idx = np.argmax(cluster_sizes) + 1
            roi_mask = (labeled == largest_idx)
            
            # Extract metrics
            peak_idx = np.unravel_index(np.argmax(zstat * roi_mask), zstat.shape)
            peak_z = zstat[peak_idx]
            centroid = nib.affines.apply_affine(affine, center_of_mass(roi_mask))
            
            # Store results
            all_results[category][session] = {
                'n_voxels': cluster_sizes[largest_idx - 1],
                'peak_z': peak_z,
                'centroid': centroid,
                'roi_mask': roi_mask
            }
            
            print(f"  ses-{session}: {cluster_sizes[largest_idx - 1]:4d} voxels, peak z={peak_z:.2f}")
    
    return all_results

# Extract functional ROIs for all subjects in analysis group
print("\n" + "="*70)
print("EXTRACTING FUNCTIONAL ROIs - CORRECTED MASKS")
print("="*70)

golarai_functional_final = {}

for subject_id in ANALYSIS_SUBJECTS.keys():
    golarai_functional_final[subject_id] = extract_functional_rois_final(subject_id, threshold_z=2.3)

print(f"\n✓ Functional ROI extraction complete for {len(golarai_functional_final)} subjects!")
# Out:
# ======================================================================
# EXTRACTING FUNCTIONAL ROIs - CORRECTED MASKS
# ======================================================================
#
# ======================================================================
# OTC004 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-01:  352 voxels, peak z=3.50
#   ses-02: 2834 voxels, peak z=6.81
#   ses-03: 4282 voxels, peak z=8.76
#   ses-05: 3798 voxels, peak z=8.69
#   ses-06: 4068 voxels, peak z=13.33
#   ses-07: cope file missing (zstat1_ses01.nii.gz)
#
# WORD:
#   ses-01:  140 voxels, peak z=3.75
#   ses-02: 5532 voxels, peak z=7.39
#   ses-03: 1423 voxels, peak z=4.58
#   ses-05: 4027 voxels, peak z=7.08
#   ses-06: 3095 voxels, peak z=6.67
#   ses-07: cope file missing (zstat1_ses01.nii.gz)
#
# OBJECT:
#   ses-01: 4369 voxels, peak z=6.77
#   ses-02: 8266 voxels, peak z=7.90
#   ses-03: 9796 voxels, peak z=8.62
#   ses-05: 15233 voxels, peak z=10.12
#   ses-06: 8469 voxels, peak z=11.29
#   ses-07: cope file missing (zstat1_ses01.nii.gz)
#
# HOUSE:
#   ses-01: 1923 voxels, peak z=5.25
#   ses-02: 3134 voxels, peak z=9.42
#   ses-03: 7855 voxels, peak z=11.75
#   ses-05: 11203 voxels, peak z=12.23
#   ses-06: 8588 voxels, peak z=12.64
#   ses-07: cope file missing (zstat1_ses01.nii.gz)
#
# ======================================================================
# nonOTC007 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 3501 voxels, peak z=9.56
#   ses-03: 6079 voxels, peak z=12.97
#   ses-04: 4215 voxels, peak z=14.58
#
# WORD:
#   ses-01:  157 voxels, peak z=4.11
#   ses-03:  930 voxels, peak z=5.04
#   ses-04:  798 voxels, peak z=5.91
#
# OBJECT:
#   ses-01: 6073 voxels, peak z=6.12
#   ses-03: 8006 voxels, peak z=7.00
#   ses-04: 14610 voxels, peak z=9.95
#
# HOUSE:
#   ses-01: 3639 voxels, peak z=9.59
#   ses-03: 9997 voxels, peak z=12.90
#   ses-04: 11944 voxels, peak z=10.72
#
# ======================================================================
# OTC008 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 9735 voxels, peak z=21.44
#   ses-02: 6803 voxels, peak z=13.71
#
# WORD:
#   ses-01: 1497 voxels, peak z=4.28
#   ses-02:  257 voxels, peak z=5.25
#
# OBJECT:
#   ses-01: 10716 voxels, peak z=16.91
#   ses-02:  744 voxels, peak z=4.75
#
# HOUSE:
#   ses-01: 15352 voxels, peak z=12.17
#   ses-02: 6970 voxels, peak z=7.25
#
# ======================================================================
# OTC010 - Functional Clusters [masks from ses-02, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-02:  300 voxels, peak z=6.48
#   ses-03:  264 voxels, peak z=5.60
#
# WORD:
#   ses-02: 1403 voxels, peak z=7.82
#   ses-03:  934 voxels, peak z=6.39
#
# OBJECT:
#   ses-02: 6983 voxels, peak z=8.67
#   ses-03: 6647 voxels, peak z=9.09
#
# HOUSE:
#   ses-02:   63 voxels, peak z=3.82
#   ses-03:  145 voxels, peak z=3.67
#
# ======================================================================
# OTC017 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 1568 voxels, peak z=9.13
#   ses-02: 1505 voxels, peak z=9.42
#   ses-03: 1231 voxels, peak z=8.23
#   ses-04: 2191 voxels, peak z=10.63
#
# WORD:
#   ses-01: 2484 voxels, peak z=6.66
#   ses-02: 2287 voxels, peak z=6.16
#   ses-03: 1480 voxels, peak z=8.46
#   ses-04: 3140 voxels, peak z=6.24
#
# OBJECT:
#   ses-01: 6039 voxels, peak z=6.94
#   ses-02: 12260 voxels, peak z=8.67
#   ses-03: 17272 voxels, peak z=10.93
#   ses-04: 15369 voxels, peak z=10.32
#
# HOUSE:
#   ses-01: 5629 voxels, peak z=10.32
#   ses-02: 1983 voxels, peak z=6.30
#   ses-03: 4988 voxels, peak z=5.66
#   ses-04: 3225 voxels, peak z=11.39
#
# ======================================================================
# OTC021 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 6761 voxels, peak z=16.10
#   ses-02: 3526 voxels, peak z=14.98
#   ses-03: 5813 voxels, peak z=18.97
#
# WORD:
#   ses-01: 4074 voxels, peak z=7.79
#   ses-02: 6304 voxels, peak z=10.83
#   ses-03: 7382 voxels, peak z=13.22
#
# OBJECT:
#   ses-01: 15731 voxels, peak z=11.52
#   ses-02: 10884 voxels, peak z=12.56
#   ses-03: 14722 voxels, peak z=13.73
#
# HOUSE:
#   ses-01: 1435 voxels, peak z=5.41
#   ses-02: 2554 voxels, peak z=8.78
#   ses-03: 4417 voxels, peak z=10.40
#
# ======================================================================
# nonOTC045 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 5448 voxels, peak z=17.55
#   ses-02: 5440 voxels, peak z=19.35
#   ses-03: 5998 voxels, peak z=16.45
#
# WORD:
#   ses-01: 2845 voxels, peak z=13.99
#   ses-02: 4130 voxels, peak z=13.37
#   ses-03: 11334 voxels, peak z=12.69
#
# OBJECT:
#   ses-01: 13586 voxels, peak z=15.30
#   ses-02: 11887 voxels, peak z=15.18
#   ses-03: 13610 voxels, peak z=13.18
#
# HOUSE:
#   ses-01: 7136 voxels, peak z=14.16
#   ses-02: 13918 voxels, peak z=17.96
#   ses-03: 8991 voxels, peak z=13.65
#
# ======================================================================
# nonOTC047 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 4502 voxels, peak z=24.01
#   ses-02: 5281 voxels, peak z=21.04
#
# WORD:
#   ses-01: 7585 voxels, peak z=14.47
#   ses-02: 4865 voxels, peak z=15.06
#
# OBJECT:
#   ses-01: 17379 voxels, peak z=16.40
#   ses-02: 19194 voxels, peak z=17.50
#
# HOUSE:
#   ses-01: 11654 voxels, peak z=17.71
#   ses-02: 10868 voxels, peak z=17.00
#
# ======================================================================
# nonOTC049 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 3940 voxels, peak z=23.86
#   ses-02: 2292 voxels, peak z=20.40
#
# WORD:
#   ses-01: 13578 voxels, peak z=24.06
#   ses-02: 12735 voxels, peak z=19.76
#
# OBJECT:
#   ses-01: 15635 voxels, peak z=24.28
#   ses-02: 11386 voxels, peak z=19.79
#
# HOUSE:
#   ses-01: 11598 voxels, peak z=17.46
#   ses-02: 8205 voxels, peak z=15.56
#
# ======================================================================
# nonOTC070 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 3465 voxels, peak z=18.21
#   ses-02: 3108 voxels, peak z=17.72
#
# WORD:
#   ses-01: 1082 voxels, peak z=6.87
#   ses-02: 3506 voxels, peak z=9.95
#
# OBJECT:
#   ses-01: 9031 voxels, peak z=11.83
#   ses-02: 11827 voxels, peak z=12.83
#
# HOUSE:
#   ses-01: 7599 voxels, peak z=15.69
#   ses-02: 7038 voxels, peak z=18.22
#
# ======================================================================
# nonOTC072 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 5092 voxels, peak z=17.16
#   ses-02: 5780 voxels, peak z=21.84
#
# WORD:
#   ses-01: 15734 voxels, peak z=10.55
#   ses-02: 17326 voxels, peak z=17.00
#
# OBJECT:
#   ses-01: 14064 voxels, peak z=10.73
#   ses-02: 12077 voxels, peak z=15.78
#
# HOUSE:
#   ses-01: 3927 voxels, peak z=11.19
#   ses-02: 1447 voxels, peak z=11.45
#
# ======================================================================
# nonOTC073 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 5345 voxels, peak z=17.27
#   ses-02: 4799 voxels, peak z=17.69
#
# WORD:
#   ses-01: 16939 voxels, peak z=12.30
#   ses-02: 14928 voxels, peak z=13.41
#
# OBJECT:
#   ses-01: 20507 voxels, peak z=18.87
#   ses-02: 20922 voxels, peak z=15.02
#
# HOUSE:
#   ses-01: 13991 voxels, peak z=14.23
#   ses-02: 7664 voxels, peak z=12.30
#
# ======================================================================
# OTC079 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 7104 voxels, peak z=21.13
#   ses-02: cope file missing (zstat1_ses01.nii.gz)
#
# WORD:
#   ses-01:  784 voxels, peak z=9.18
#   ses-02: cope file missing (zstat1_ses01.nii.gz)
#
# OBJECT:
#   ses-01: 9954 voxels, peak z=13.00
#   ses-02: cope file missing (zstat1_ses01.nii.gz)
#
# HOUSE:
#   ses-01: 9965 voxels, peak z=15.88
#   ses-02: cope file missing (zstat1_ses01.nii.gz)
#
# ======================================================================
# nonOTC081 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 1479 voxels, peak z=16.08
#   ses-02: 1086 voxels, peak z=11.40
#
# WORD:
#   ses-01: 2136 voxels, peak z=8.05
#   ses-02: 1980 voxels, peak z=5.32
#
# OBJECT:
#   ses-01: 8804 voxels, peak z=16.02
#   ses-02: 7516 voxels, peak z=12.84
#
# HOUSE:
#   ses-01: 5094 voxels, peak z=11.32
#   ses-02: 3063 voxels, peak z=8.23
#
# ======================================================================
# nonOTC086 - Functional Clusters [masks from ses-01, z>2.3] [nonOTC patient]
# ======================================================================
#
# FACE:
#   ses-01: 4335 voxels, peak z=22.57
#   ses-02: 4521 voxels, peak z=22.41
#
# WORD:
#   ses-01: 9318 voxels, peak z=12.11
#   ses-02: 5691 voxels, peak z=10.89
#
# OBJECT:
#   ses-01: 7674 voxels, peak z=9.83
#   ses-02: 10412 voxels, peak z=8.83
#
# HOUSE:
#   ses-01: 4856 voxels, peak z=7.92
#   ses-02: 3206 voxels, peak z=5.71
#
# ======================================================================
# OTC108 - Functional Clusters [masks from ses-01, z>2.3] [OTC patient]
# ======================================================================
#
# FACE:
#   ⚠️  Mask not found: /user_data/csimmon2/long_pt/sub-108/ses-01/ROIs/r_face_searchmask.nii.gz
#
# WORD:
#   ⚠️  Mask not found: /user_data/csimmon2/long_pt/sub-108/ses-01/ROIs/r_word_searchmask.nii.gz
#
# OBJECT:
#   ⚠️  Mask not found: /user_data/csimmon2/long_pt/sub-108/ses-01/ROIs/r_object_searchmask.nii.gz
#
# HOUSE:
#   ⚠️  Mask not found: /user_data/csimmon2/long_pt/sub-108/ses-01/ROIs/r_house_searchmask.nii.gz
#
# ======================================================================
# control018 - Functional Clusters [masks from ses-02, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-02: 5227 voxels, peak z=17.31
#   ses-03: 2401 voxels, peak z=13.89
#
# WORD:
#   ses-02: 4006 voxels, peak z=12.74
#   ses-03: 2481 voxels, peak z=10.98
#
# OBJECT:
#   ses-02: 17411 voxels, peak z=16.43
#   ses-03: 9189 voxels, peak z=10.76
#
# HOUSE:
#   ses-02: 18270 voxels, peak z=19.02
#   ses-03: 13150 voxels, peak z=15.08
#
# ======================================================================
# control022 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 2018 voxels, peak z=12.40
#   ses-02: 6203 voxels, peak z=16.03
#
# WORD:
#   ses-01: 1284 voxels, peak z=6.57
#   ses-02: 8730 voxels, peak z=7.81
#
# OBJECT:
#   ses-01: 2548 voxels, peak z=7.93
#   ses-02: 12593 voxels, peak z=12.17
#
# HOUSE:
#   ses-01: 4249 voxels, peak z=11.53
#   ses-02: 19986 voxels, peak z=18.41
#
# ======================================================================
# control025 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 5217 voxels, peak z=18.55
#   ses-02: 8476 voxels, peak z=20.95
#
# WORD:
#   ses-01: 1499 voxels, peak z=11.55
#   ses-02: 4207 voxels, peak z=12.83
#
# OBJECT:
#   ses-01: 15847 voxels, peak z=11.90
#   ses-02: 18058 voxels, peak z=16.42
#
# HOUSE:
#   ses-01: 9742 voxels, peak z=10.97
#   ses-02: 12330 voxels, peak z=16.04
#
# ======================================================================
# control027 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 4451 voxels, peak z=8.62
#   ses-02: 2666 voxels, peak z=13.35
#
# WORD:
#   ses-01: 3130 voxels, peak z=6.22
#   ses-02: 4385 voxels, peak z=7.82
#
# OBJECT:
#   ses-01: 6768 voxels, peak z=6.07
#   ses-02: 21312 voxels, peak z=10.25
#
# HOUSE:
#   ses-01: 6515 voxels, peak z=7.48
#   ses-02: 10945 voxels, peak z=9.58
#
# ======================================================================
# control052 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 8722 voxels, peak z=14.01
#   ses-02: 5433 voxels, peak z=15.06
#
# WORD:
#   ses-01: 15416 voxels, peak z=5.59
#   ses-02: 6471 voxels, peak z=9.48
#
# OBJECT:
#   ses-01: 16920 voxels, peak z=10.31
#   ses-02: 10666 voxels, peak z=8.31
#
# HOUSE:
#   ses-01: 26834 voxels, peak z=14.54
#   ses-02: 9885 voxels, peak z=14.80
#
# ======================================================================
# control058 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 2316 voxels, peak z=12.90
#   ses-02: 1902 voxels, peak z=13.76
#
# WORD:
#   ses-01: 1612 voxels, peak z=8.33
#   ses-02: 1736 voxels, peak z=7.85
#
# OBJECT:
#   ses-01: 8875 voxels, peak z=10.35
#   ses-02: 5047 voxels, peak z=7.73
#
# HOUSE:
#   ses-01: 1672 voxels, peak z=8.27
#   ses-02: 2310 voxels, peak z=10.66
#
# ======================================================================
# control062 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 3549 voxels, peak z=18.15
#   ses-02: 2506 voxels, peak z=18.59
#
# WORD:
#   ses-01:  402 voxels, peak z=4.83
#   ses-02:  926 voxels, peak z=7.46
#
# OBJECT:
#   ses-01: 8073 voxels, peak z=10.62
#   ses-02: 3976 voxels, peak z=9.25
#
# HOUSE:
#   ses-01: 5466 voxels, peak z=17.84
#   ses-02: 4940 voxels, peak z=17.00
#
# ======================================================================
# control064 - Functional Clusters [masks from ses-01, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-01: 2423 voxels, peak z=16.17
#   ses-02: 2153 voxels, peak z=15.60
#
# WORD:
#   ses-01: 1521 voxels, peak z=4.74
#   ses-02: 7892 voxels, peak z=11.65
#
# OBJECT:
#   ses-01: 10148 voxels, peak z=9.60
#   ses-02: 9672 voxels, peak z=9.51
#
# HOUSE:
#   ses-01: 5301 voxels, peak z=10.45
#   ses-02: 6593 voxels, peak z=9.95
#
# ======================================================================
# control068 - Functional Clusters [masks from ses-02, z>2.3] [control control]
# ======================================================================
#
# FACE:
#   ses-02: 6463 voxels, peak z=20.58
#   ses-03: 5850 voxels, peak z=18.46
#
# WORD:
#   ses-02: 6203 voxels, peak z=11.37
#   ses-03: 1066 voxels, peak z=6.60
#
# OBJECT:
#   ses-02: 15158 voxels, peak z=10.99
#   ses-03: 10913 voxels, peak z=10.50
#
# HOUSE:
#   ses-02: 11092 voxels, peak z=12.26
#   ses-03: 12771 voxels, peak z=11.90
#
# ✓ Functional ROI extraction complete for 25 subjects!

# %%
# CELL 7: Analysis Summary and Group Comparison
def summarize_analysis_results(functional_results, subjects_dict):
    """
    Create summary of analysis results by group
    """
    
    print("\n" + "="*70)
    print("ANALYSIS SUMMARY BY GROUP")
    print("="*70)
    
    # Group by patient status and group
    groups = {}
    for subject_id, info in subjects_dict.items():
        group_key = f"{info['group']}_{info['patient_status']}"
        if group_key not in groups:
            groups[group_key] = []
        groups[group_key].append(subject_id)
    
    # Summary by category
    for category in CATEGORY_PARCELS.keys():
        print(f"\n{category.upper()} CATEGORY:")
        print("-" * 50)
        
        for group_key, subject_list in groups.items():
            print(f"\n{group_key}:")
            
            session_data = {}
            for subject_id in subject_list:
                if subject_id in functional_results and category in functional_results[subject_id]:
                    for session, data in functional_results[subject_id][category].items():
                        if session not in session_data:
                            session_data[session] = []
                        session_data[session].append(data['n_voxels'])
            
            for session in sorted(session_data.keys()):
                voxels = session_data[session]
                if voxels:
                    mean_voxels = np.mean(voxels)
                    print(f"  ses-{session}: {len(voxels)} subjects, mean={mean_voxels:.1f} voxels")
    
    # Subject completion rates
    print(f"\n{'='*70}")
    print("SUBJECT COMPLETION RATES")
    print(f"{'='*70}")
    
    for subject_id, info in subjects_dict.items():
        code = info['code']
        group_status = f"{info['group']} {info['patient_status']}"
        
        if subject_id in functional_results:
            categories_found = len(functional_results[subject_id])
            sessions_per_category = {}
            
            for cat, sessions in functional_results[subject_id].items():
                sessions_per_category[cat] = len(sessions)
            
            print(f"{code:10s} ({group_status:15s}): {categories_found}/4 categories, sessions: {dict(sessions_per_category)}")
        else:
            print(f"{code:10s} ({group_status:15s}): No functional data")

# Generate summary for current analysis
summarize_analysis_results(golarai_functional_final, ANALYSIS_SUBJECTS)

print(f"\n✓ Analysis complete for {len(ANALYSIS_SUBJECTS)} subjects")
print(f"✓ Data ready for RSA analysis")
print(f"✓ Results saved to: {OUTPUT_DIR}")
# Out:
# ======================================================================
# ANALYSIS SUMMARY BY GROUP
# ======================================================================
#
# FACE CATEGORY:
# --------------------------------------------------
#
# OTC_patient:
#   ses-01: 5 subjects, mean=5104.0 voxels
#   ses-02: 5 subjects, mean=2993.6 voxels
#   ses-03: 4 subjects, mean=2897.5 voxels
#   ses-04: 1 subjects, mean=2191.0 voxels
#   ses-05: 1 subjects, mean=3798.0 voxels
#   ses-06: 1 subjects, mean=4068.0 voxels
#
# nonOTC_patient:
#   ses-01: 9 subjects, mean=4123.0 voxels
#   ses-02: 8 subjects, mean=4038.4 voxels
#   ses-03: 2 subjects, mean=6038.5 voxels
#   ses-04: 1 subjects, mean=4215.0 voxels
#
# control_control:
#   ses-01: 7 subjects, mean=4099.4 voxels
#   ses-02: 9 subjects, mean=4558.8 voxels
#   ses-03: 2 subjects, mean=4125.5 voxels
#
# WORD CATEGORY:
# --------------------------------------------------
#
# OTC_patient:
#   ses-01: 5 subjects, mean=1795.8 voxels
#   ses-02: 5 subjects, mean=3156.6 voxels
#   ses-03: 4 subjects, mean=2804.8 voxels
#   ses-04: 1 subjects, mean=3140.0 voxels
#   ses-05: 1 subjects, mean=4027.0 voxels
#   ses-06: 1 subjects, mean=3095.0 voxels
#
# nonOTC_patient:
#   ses-01: 9 subjects, mean=7708.2 voxels
#   ses-02: 8 subjects, mean=8145.1 voxels
#   ses-03: 2 subjects, mean=6132.0 voxels
#   ses-04: 1 subjects, mean=798.0 voxels
#
# control_control:
#   ses-01: 7 subjects, mean=3552.0 voxels
#   ses-02: 9 subjects, mean=4950.7 voxels
#   ses-03: 2 subjects, mean=1773.5 voxels
#
# OBJECT CATEGORY:
# --------------------------------------------------
#
# OTC_patient:
#   ses-01: 5 subjects, mean=9361.8 voxels
#   ses-02: 5 subjects, mean=7827.4 voxels
#   ses-03: 4 subjects, mean=12109.2 voxels
#   ses-04: 1 subjects, mean=15369.0 voxels
#   ses-05: 1 subjects, mean=15233.0 voxels
#   ses-06: 1 subjects, mean=8469.0 voxels
#
# nonOTC_patient:
#   ses-01: 9 subjects, mean=12528.1 voxels
#   ses-02: 8 subjects, mean=13152.6 voxels
#   ses-03: 2 subjects, mean=10808.0 voxels
#   ses-04: 1 subjects, mean=14610.0 voxels
#
# control_control:
#   ses-01: 7 subjects, mean=9882.7 voxels
#   ses-02: 9 subjects, mean=12654.8 voxels
#   ses-03: 2 subjects, mean=10051.0 voxels
#
# HOUSE CATEGORY:
# --------------------------------------------------
#
# OTC_patient:
#   ses-01: 5 subjects, mean=6860.8 voxels
#   ses-02: 5 subjects, mean=2940.8 voxels
#   ses-03: 4 subjects, mean=4351.2 voxels
#   ses-04: 1 subjects, mean=3225.0 voxels
#   ses-05: 1 subjects, mean=11203.0 voxels
#   ses-06: 1 subjects, mean=8588.0 voxels
#
# nonOTC_patient:
#   ses-01: 9 subjects, mean=7721.6 voxels
#   ses-02: 8 subjects, mean=6926.1 voxels
#   ses-03: 2 subjects, mean=9494.0 voxels
#   ses-04: 1 subjects, mean=11944.0 voxels
#
# control_control:
#   ses-01: 7 subjects, mean=8539.9 voxels
#   ses-02: 9 subjects, mean=10705.7 voxels
#   ses-03: 2 subjects, mean=12960.5 voxels
#
# ======================================================================
# SUBJECT COMPLETION RATES
# ======================================================================
# OTC004     (OTC patient    ): 4/4 categories, sessions: {'face': 5, 'word': 5, 'object': 5, 'house': 5}
# nonOTC007  (nonOTC patient ): 4/4 categories, sessions: {'face': 3, 'word': 3, 'object': 3, 'house': 3}
# OTC008     (OTC patient    ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# OTC010     (OTC patient    ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# OTC017     (OTC patient    ): 4/4 categories, sessions: {'face': 4, 'word': 4, 'object': 4, 'house': 4}
# OTC021     (OTC patient    ): 4/4 categories, sessions: {'face': 3, 'word': 3, 'object': 3, 'house': 3}
# nonOTC045  (nonOTC patient ): 4/4 categories, sessions: {'face': 3, 'word': 3, 'object': 3, 'house': 3}
# nonOTC047  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# nonOTC049  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# nonOTC070  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# nonOTC072  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# nonOTC073  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# OTC079     (OTC patient    ): 4/4 categories, sessions: {'face': 1, 'word': 1, 'object': 1, 'house': 1}
# nonOTC081  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# nonOTC086  (nonOTC patient ): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# OTC108     (OTC patient    ): 4/4 categories, sessions: {'face': 0, 'word': 0, 'object': 0, 'house': 0}
# control018 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control022 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control025 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control027 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control052 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control058 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control062 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control064 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
# control068 (control control): 4/4 categories, sessions: {'face': 2, 'word': 2, 'object': 2, 'house': 2}
#
# ✓ Analysis complete for 25 subjects
# ✓ Data ready for RSA analysis
# ✓ Results saved to: /user_data/csimmon2/long_pt/analyses/rsa_corrected

# %%
# CELL 8: Calculate peak drift (Updated for Dynamic Subjects)
def calculate_peak_drift(functional_results, subjects_dict):
    """Calculate total drift for each category using dynamic subjects"""
    print("\nPeak Movement Summary:")
    print(f"{'Subject':<10} {'Category':<8} {'Total Drift (mm)':<18} {'Sessions'}")
    print("-"*75)
    
    for subj in subjects_dict.keys():  # Use dynamic subjects
        info = subjects_dict[subj]
        code = info['code']
        
        if subj not in functional_results:
            continue
            
        for cat in ['face', 'word', 'object', 'house']:
            if cat not in functional_results[subj]:
                continue
            sessions = sorted(functional_results[subj][cat].keys())
            if len(sessions) < 2:
                continue
            
            first = functional_results[subj][cat][sessions[0]]['centroid']
            last = functional_results[subj][cat][sessions[-1]]['centroid']
            drift = np.linalg.norm(last - first)
            
            group_status = f"{info['group']}/{info['patient_status']}"
            print(f"{code:<10} {cat:<8} {drift:>10.1f} mm        {', '.join(sessions)} [{group_status}]")

calculate_peak_drift(golarai_functional_final, ANALYSIS_SUBJECTS)
# Out:
# Peak Movement Summary:
# Subject    Category Total Drift (mm)   Sessions
# ---------------------------------------------------------------------------
# OTC004     face           11.1 mm        01, 02, 03, 05, 06 [OTC/patient]
# OTC004     word           35.2 mm        01, 02, 03, 05, 06 [OTC/patient]
# OTC004     object          3.7 mm        01, 02, 03, 05, 06 [OTC/patient]
# OTC004     house          11.5 mm        01, 02, 03, 05, 06 [OTC/patient]
# nonOTC007  face            3.4 mm        01, 03, 04 [nonOTC/patient]
# nonOTC007  word           12.4 mm        01, 03, 04 [nonOTC/patient]
# nonOTC007  object          5.4 mm        01, 03, 04 [nonOTC/patient]
# nonOTC007  house           8.5 mm        01, 03, 04 [nonOTC/patient]
# OTC008     face            9.0 mm        01, 02 [OTC/patient]
# OTC008     word           78.5 mm        01, 02 [OTC/patient]
# OTC008     object          9.4 mm        01, 02 [OTC/patient]
# OTC008     house           5.8 mm        01, 02 [OTC/patient]
# OTC010     face            3.8 mm        02, 03 [OTC/patient]
# OTC010     word           50.7 mm        02, 03 [OTC/patient]
# OTC010     object          3.7 mm        02, 03 [OTC/patient]
# OTC010     house          15.6 mm        02, 03 [OTC/patient]
# OTC017     face           14.1 mm        01, 02, 03, 04 [OTC/patient]
# OTC017     word           61.5 mm        01, 02, 03, 04 [OTC/patient]
# OTC017     object         12.1 mm        01, 02, 03, 04 [OTC/patient]
# OTC017     house           6.5 mm        01, 02, 03, 04 [OTC/patient]
# OTC021     face            4.4 mm        01, 02, 03 [OTC/patient]
# OTC021     word            2.0 mm        01, 02, 03 [OTC/patient]
# OTC021     object          3.4 mm        01, 02, 03 [OTC/patient]
# OTC021     house           4.2 mm        01, 02, 03 [OTC/patient]
# nonOTC045  face            2.4 mm        01, 02, 03 [nonOTC/patient]
# nonOTC045  word           26.5 mm        01, 02, 03 [nonOTC/patient]
# nonOTC045  object          1.7 mm        01, 02, 03 [nonOTC/patient]
# nonOTC045  house           1.2 mm        01, 02, 03 [nonOTC/patient]
# nonOTC047  face            6.0 mm        01, 02 [nonOTC/patient]
# nonOTC047  word            3.4 mm        01, 02 [nonOTC/patient]
# nonOTC047  object          3.2 mm        01, 02 [nonOTC/patient]
# nonOTC047  house           3.9 mm        01, 02 [nonOTC/patient]
# nonOTC049  face            5.9 mm        01, 02 [nonOTC/patient]
# nonOTC049  word            6.2 mm        01, 02 [nonOTC/patient]
# nonOTC049  object          2.6 mm        01, 02 [nonOTC/patient]
# nonOTC049  house           4.0 mm        01, 02 [nonOTC/patient]
# nonOTC070  face            3.1 mm        01, 02 [nonOTC/patient]
# nonOTC070  word            6.1 mm        01, 02 [nonOTC/patient]
# nonOTC070  object          3.5 mm        01, 02 [nonOTC/patient]
# nonOTC070  house           2.2 mm        01, 02 [nonOTC/patient]
# nonOTC072  face            1.2 mm        01, 02 [nonOTC/patient]
# nonOTC072  word            8.6 mm        01, 02 [nonOTC/patient]
# nonOTC072  object          0.6 mm        01, 02 [nonOTC/patient]
# nonOTC072  house           6.7 mm        01, 02 [nonOTC/patient]
# nonOTC073  face            3.5 mm        01, 02 [nonOTC/patient]
# nonOTC073  word            2.2 mm        01, 02 [nonOTC/patient]
# nonOTC073  object          0.5 mm        01, 02 [nonOTC/patient]
# nonOTC073  house           5.3 mm        01, 02 [nonOTC/patient]
# nonOTC081  face            1.5 mm        01, 02 [nonOTC/patient]
# nonOTC081  word            2.3 mm        01, 02 [nonOTC/patient]
# nonOTC081  object          1.9 mm        01, 02 [nonOTC/patient]
# nonOTC081  house           6.4 mm        01, 02 [nonOTC/patient]
# nonOTC086  face            1.0 mm        01, 02 [nonOTC/patient]
# nonOTC086  word            7.5 mm        01, 02 [nonOTC/patient]
# nonOTC086  object          1.0 mm        01, 02 [nonOTC/patient]
# nonOTC086  house           4.7 mm        01, 02 [nonOTC/patient]
# control018 face            9.3 mm        02, 03 [control/control]
# control018 word            1.3 mm        02, 03 [control/control]
# control018 object          5.6 mm        02, 03 [control/control]
# control018 house           6.9 mm        02, 03 [control/control]
# control022 face           16.3 mm        01, 02 [control/control]
# control022 word           10.7 mm        01, 02 [control/control]
# control022 object         11.5 mm        01, 02 [control/control]
# control022 house           3.4 mm        01, 02 [control/control]
# control025 face            6.1 mm        01, 02 [control/control]
# control025 word            2.7 mm        01, 02 [control/control]
# control025 object          3.6 mm        01, 02 [control/control]
# control025 house           5.1 mm        01, 02 [control/control]
# control027 face            5.0 mm        01, 02 [control/control]
# control027 word            9.5 mm        01, 02 [control/control]
# control027 object          7.5 mm        01, 02 [control/control]
# control027 house           4.0 mm        01, 02 [control/control]
# control052 face            2.6 mm        01, 02 [control/control]
# control052 word           80.7 mm        01, 02 [control/control]
# control052 object          7.2 mm        01, 02 [control/control]
# control052 house           9.1 mm        01, 02 [control/control]
# control058 face            1.6 mm        01, 02 [control/control]
# control058 word            1.8 mm        01, 02 [control/control]
# control058 object          4.9 mm        01, 02 [control/control]
# control058 house           1.3 mm        01, 02 [control/control]
# control062 face            1.8 mm        01, 02 [control/control]
# control062 word            6.0 mm        01, 02 [control/control]
# control062 object          5.2 mm        01, 02 [control/control]
# control062 house           0.5 mm        01, 02 [control/control]
# control064 face            7.4 mm        01, 02 [control/control]
# control064 word           22.8 mm        01, 02 [control/control]
# control064 object          1.7 mm        01, 02 [control/control]
# control064 house           5.4 mm        01, 02 [control/control]
# control068 face            0.3 mm        02, 03 [control/control]
# control068 word           17.8 mm        02, 03 [control/control]
# control068 object          6.0 mm        02, 03 [control/control]
# control068 house           3.3 mm        02, 03 [control/control]

# %%
# CELL 9: Simple Peak Summary (Skip Plotting Issues)
import pandas as pd

def create_peak_summary_table(functional_results, subjects_dict):
    """Create a comprehensive table of all peaks"""
    
    rows = []
    
    for subject_id, info in subjects_dict.items():
        if subject_id not in functional_results:
            continue
            
        code = info['code']
        group = info['group']
        patient_status = info['patient_status']
        
        for category in ['face', 'word', 'object', 'house']:
            if category not in functional_results[subject_id]:
                continue
                
            sessions = list(functional_results[subject_id][category].keys())
            n_sessions = len(sessions)
            
            # Calculate drift if multiple sessions
            if n_sessions > 1:
                first_peak = functional_results[subject_id][category][sessions[0]]['centroid']
                last_peak = functional_results[subject_id][category][sessions[-1]]['centroid']
                drift = np.linalg.norm(np.array(last_peak) - np.array(first_peak))
            else:
                drift = 0
            
            # Add row for each session
            for session in sessions:
                data = functional_results[subject_id][category][session]
                rows.append({
                    'Subject': code,
                    'Group': group,
                    'Status': patient_status,
                    'Category': category,
                    'Session': session,
                    'X': data['centroid'][0],
                    'Y': data['centroid'][1], 
                    'Z': data['centroid'][2],
                    'N_Voxels': data['n_voxels'],
                    'Peak_Z': data['peak_z'],
                    'Total_Drift': drift if session == sessions[-1] else None
                })
    
    return pd.DataFrame(rows)

# Create comprehensive summary
print("\n" + "="*70)
print("FUNCTIONAL PEAK SUMMARY TABLE")
print("="*70)

peak_summary = create_peak_summary_table(golarai_functional_final, ANALYSIS_SUBJECTS)

# Display by group
for group in peak_summary['Group'].unique():
    print(f"\n{group.upper()} GROUP:")
    print("-" * 50)
    
    group_data = peak_summary[peak_summary['Group'] == group]
    
    # Show summary stats
    for category in ['face', 'word', 'object', 'house']:
        cat_data = group_data[group_data['Category'] == category]
        if len(cat_data) > 0:
            n_subjects = cat_data['Subject'].nunique()
            total_sessions = len(cat_data)
            avg_voxels = cat_data['N_Voxels'].mean()
            print(f"  {category:8s}: {n_subjects:2d} subjects, {total_sessions:2d} sessions, avg {avg_voxels:5.0f} voxels")

# Save full table
output_file = OUTPUT_DIR / 'functional_peaks_summary.csv'
peak_summary.to_csv(output_file, index=False)
print(f"\n✓ Full table saved to: {output_file}")

# Show drift analysis
print("\n" + "="*70)
print("DRIFT ANALYSIS (subjects with multiple sessions)")
print("="*70)

drift_data = peak_summary[peak_summary['Total_Drift'].notna()]
if len(drift_data) > 0:
    print(f"{'Subject':<10} {'Category':<8} {'Drift (mm)':<12} {'Sessions':<10} {'Group'}")
    print("-" * 60)
    for _, row in drift_data.iterrows():
        sessions = peak_summary[(peak_summary['Subject'] == row['Subject']) & 
                              (peak_summary['Category'] == row['Category'])]['Session'].tolist()
        session_str = f"{sessions[0]}-{sessions[-1]}"
        print(f"{row['Subject']:<10} {row['Category']:<8} {row['Total_Drift']:>8.1f}        {session_str:<10} {row['Group']}")
else:
    print("No multi-session data found")

print(f"\n✓ Analysis complete for {len(ANALYSIS_SUBJECTS)} subjects")
# Out:
# ======================================================================
# FUNCTIONAL PEAK SUMMARY TABLE
# ======================================================================
#
# OTC GROUP:
# --------------------------------------------------
#   face    :  6 subjects, 17 sessions, avg  3571 voxels
#   word    :  6 subjects, 15 sessions, avg  1132 voxels
#   object  :  6 subjects, 17 sessions, avg  7515 voxels
#   house   :  6 subjects, 17 sessions, avg  2299 voxels
#
# NONOTC GROUP:
# --------------------------------------------------
#   face    :  9 subjects, 20 sessions, avg  4271 voxels
#   word    :  9 subjects, 19 sessions, avg  2056 voxels
#   object  :  9 subjects, 20 sessions, avg  8075 voxels
#   house   :  9 subjects, 20 sessions, avg  3893 voxels
#
# CONTROL GROUP:
# --------------------------------------------------
#   face    :  7 subjects, 14 sessions, avg  4022 voxels
#   word    :  7 subjects, 14 sessions, avg  1318 voxels
#   object  :  7 subjects, 14 sessions, avg  7696 voxels
#   house   :  7 subjects, 14 sessions, avg  4929 voxels
#
# ✓ Full table saved to: /user_data/csimmon2/long_pt/analyses/rsa_corrected/functional_peaks_summary.csv
#
# ======================================================================
# DRIFT ANALYSIS (subjects with multiple sessions)
# ======================================================================
# Subject    Category Drift (mm)   Sessions   Group
# ------------------------------------------------------------
# OTC004     face         11.1        01-06      OTC
# OTC004     word         24.4        02-06      OTC
# OTC004     object        3.2        01-06      OTC
# OTC004     house        14.5        01-06      OTC
# nonOTC007  face          3.6        01-04      nonOTC
# nonOTC007  word         18.5        03-04      nonOTC
# nonOTC007  object        3.7        01-04      nonOTC
# nonOTC007  house         9.6        01-04      nonOTC
# OTC008     face          6.6        01-02      OTC
# OTC008     word          0.0        02-02      OTC
# OTC008     object       11.4        01-02      OTC
# OTC008     house         6.4        01-02      OTC
# OTC010     face          3.8        02-03      OTC
# OTC010     word         22.1        02-03      OTC
# OTC010     object        2.7        02-03      OTC
# OTC010     house        49.9        02-03      OTC
# OTC017     face         13.9        01-04      OTC
# OTC017     word         30.5        01-04      OTC
# OTC017     object        7.7        01-04      OTC
# OTC017     house         5.2        01-04      OTC
# OTC021     face          4.6        01-03      OTC
# OTC021     word         13.7        01-03      OTC
# OTC021     object        4.7        01-03      OTC
# OTC021     house         2.1        01-03      OTC
# nonOTC045  face          2.4        01-03      nonOTC
# nonOTC045  word          1.8        01-03      nonOTC
# nonOTC045  object        1.1        01-03      nonOTC
# nonOTC045  house         1.5        01-03      nonOTC
# nonOTC047  face          6.0        01-02      nonOTC
# nonOTC047  word          2.2        01-02      nonOTC
# nonOTC047  object        1.6        01-02      nonOTC
# nonOTC047  house         6.5        01-02      nonOTC
# nonOTC049  face          5.9        01-02      nonOTC
# nonOTC049  word          2.3        01-02      nonOTC
# nonOTC049  object        2.2        01-02      nonOTC
# nonOTC049  house         5.6        01-02      nonOTC
# nonOTC070  face          2.9        01-02      nonOTC
# nonOTC070  word          1.5        01-02      nonOTC
# nonOTC070  object        2.9        01-02      nonOTC
# nonOTC070  house         3.9        01-02      nonOTC
# nonOTC072  face          1.2        01-02      nonOTC
# nonOTC072  word          1.4        01-02      nonOTC
# nonOTC072  object        0.9        01-02      nonOTC
# nonOTC072  house         3.6        01-02      nonOTC
# nonOTC073  face          3.3        01-02      nonOTC
# nonOTC073  word          1.1        01-02      nonOTC
# nonOTC073  object        0.4        01-02      nonOTC
# nonOTC073  house         7.4        01-02      nonOTC
# OTC079     face          0.0        01-01      OTC
# OTC079     word          0.0        01-01      OTC
# OTC079     object        0.0        01-01      OTC
# OTC079     house         0.0        01-01      OTC
# nonOTC081  face          1.5        01-02      nonOTC
# nonOTC081  word         35.0        01-02      nonOTC
# nonOTC081  object        3.0        01-02      nonOTC
# nonOTC081  house         5.4        01-02      nonOTC
# nonOTC086  face          0.5        01-02      nonOTC
# nonOTC086  word          2.0        01-02      nonOTC
# nonOTC086  object        4.0        01-02      nonOTC
# nonOTC086  house         1.5        01-02      nonOTC
# control022 face         16.1        01-02      control
# control022 word         26.2        01-02      control
# control022 object        6.4        01-02      control
# control022 house         8.6        01-02      control
# control025 face          5.2        01-02      control
# control025 word          7.8        01-02      control
# control025 object        1.1        01-02      control
# control025 house         6.8        01-02      control
# control027 face          5.9        01-02      control
# control027 word          4.9        01-02      control
# control027 object        9.1        01-02      control
# control027 house         3.2        01-02      control
# control052 face          2.5        01-02      control
# control052 word         14.6        01-02      control
# control052 object        3.4        01-02      control
# control052 house        19.9        01-02      control
# control058 face          1.6        01-02      control
# control058 word         11.0        01-02      control
# control058 object        2.3        01-02      control
# control058 house         2.0        01-02      control
# control062 face          1.2        01-02      control
# control062 word          1.7        01-02      control
# control062 object        2.1        01-02      control
# control062 house         0.6        01-02      control
# control064 face          7.4        01-02      control
# control064 word          6.3        01-02      control
# control064 object        1.2        01-02      control
# control064 house         3.9        01-02      control
#
# ✓ Analysis complete for 25 subjects

# %%
# CELL 10: Comprehensive Mask Visualization for All Subjects
from nilearn import plotting, image
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

def plot_all_masks_on_anatomy():
    """Generate mask overlays for all subjects and categories"""
    
    print("COMPREHENSIVE MASK VISUALIZATION")
    print("="*70)
    
    # Create organized output directory
    mask_viz_dir = OUTPUT_DIR / "mask_visualizations"
    mask_viz_dir.mkdir(exist_ok=True)
    
    # Track statistics
    stats = {
        'subjects_processed': 0,
        'subjects_with_anatomy': 0,
        'total_masks_found': 0,
        'total_masks_plotted': 0,
        'missing_anatomy': [],
        'missing_masks': {},
        'potential_issues': []
    }
    
    categories = ['face', 'word', 'object', 'house']
    color_map = {'face': 'Reds', 'word': 'Blues', 'object': 'Greens', 'house': 'Oranges'}
    
    # Process each subject
    for subject_id, info in ANALYSIS_SUBJECTS.items():
        code = info['code']
        first_session = info['sessions'][0]
        hemi = info['hemi']
        group = info['group']
        patient_status = info['patient_status']
        
        stats['subjects_processed'] += 1
        
        print(f"\n{code} ({group} {patient_status}) - ses-{first_session}, hemisphere: {hemi}")
        
        # Check anatomy file
        anat_path = BASE_DIR / subject_id / f'ses-{first_session}' / 'anat' / f'{subject_id}_ses-{first_session}_T1w_brain.nii.gz'
        
        if not anat_path.exists():
            print(f"  ❌ No anatomy file")
            stats['missing_anatomy'].append(code)
            continue
        
        stats['subjects_with_anatomy'] += 1
        anat_img = image.load_img(anat_path)
        
        # Check ROI directory
        roi_dir = BASE_DIR / subject_id / f'ses-{first_session}' / 'ROIs'
        if not roi_dir.exists():
            print(f"  ❌ No ROI directory")
            continue
        
        # Process each category
        subject_masks_found = 0
        subject_masks_plotted = 0
        
        for category in categories:
            mask_file = roi_dir / f'{hemi}_{category}_searchmask.nii.gz'
            
            if not mask_file.exists():
                print(f"    ❌ {category}: no {hemi} mask")
                if code not in stats['missing_masks']:
                    stats['missing_masks'][code] = []
                stats['missing_masks'][code].append(f"{hemi}_{category}")
                continue
            
            stats['total_masks_found'] += 1
            subject_masks_found += 1
            
            try:
                # Load mask
                mask_img = image.load_img(mask_file)
                mask_data = mask_img.get_fdata()
                
                if (mask_data > 0).sum() == 0:
                    print(f"    ⚠️  {category}: empty mask")
                    continue
                
                # Get mask center for positioning
                mask_com = center_of_mass(mask_data > 0)
                mask_com_world = nib.affines.apply_affine(mask_img.affine, mask_com)
                
                # Check for potential issues
                x_coord = mask_com_world[0]
                if hemi == 'l' and x_coord > 5:
                    stats['potential_issues'].append(f"{code}_{category}: 'left' mask center at x={x_coord:.1f} (right side)")
                elif hemi == 'r' and x_coord < -5:
                    stats['potential_issues'].append(f"{code}_{category}: 'right' mask center at x={x_coord:.1f} (left side)")
                
                # Create visualization
                fig = plt.figure(figsize=(12, 8))
                
                display = plotting.plot_anat(
                    anat_img,
                    display_mode='ortho',
                    cut_coords=(mask_com_world[0], mask_com_world[1], mask_com_world[2]),
                    draw_cross=True,
                    annotate=False,
                    black_bg=False,
                    title=f'{code} - {hemi}_{category} mask'
                )
                
                # Overlay mask
                display.add_overlay(
                    mask_img,
                    cmap=color_map[category],
                    alpha=0.7,
                    threshold=0.1
                )
                
                # Add info text
                info_text = f'Center: x={mask_com_world[0]:.1f}, y={mask_com_world[1]:.1f}, z={mask_com_world[2]:.1f}\nVoxels: {(mask_data > 0).sum()}'
                plt.figtext(0.02, 0.02, info_text, 
                           fontsize=9, bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8))
                
                # Save
                output_file = mask_viz_dir / f'{code}_{hemi}_{category}_mask.png'
                plt.savefig(output_file, dpi=200, bbox_inches='tight')
                plt.close(fig)  # Close to save memory
                
                stats['total_masks_plotted'] += 1
                subject_masks_plotted += 1
                
                print(f"    ✅ {category}: plotted ({(mask_data > 0).sum()} voxels, center x={x_coord:.1f})")
                
            except Exception as e:
                print(f"    ❌ {category}: error - {e}")
        
        print(f"  → {subject_masks_plotted}/{len(categories)} masks plotted")
    
    # Generate summary report
    print(f"\n" + "="*70)
    print("VISUALIZATION SUMMARY REPORT")
    print("="*70)
    
    print(f"Subjects processed: {stats['subjects_processed']}")
    print(f"Subjects with anatomy: {stats['subjects_with_anatomy']}")
    print(f"Total masks found: {stats['total_masks_found']}")
    print(f"Total masks plotted: {stats['total_masks_plotted']}")
    
    if stats['missing_anatomy']:
        print(f"\nSubjects missing anatomy ({len(stats['missing_anatomy'])}):")
        for code in stats['missing_anatomy']:
            print(f"  {code}")
    
    if stats['missing_masks']:
        print(f"\nSubjects with missing masks:")
        for code, missing in stats['missing_masks'].items():
            print(f"  {code}: {missing}")
    
    if stats['potential_issues']:
        print(f"\nPotential hemisphere labeling issues ({len(stats['potential_issues'])}):")
        for issue in stats['potential_issues']:
            print(f"  {issue}")
    
    print(f"\n✅ All visualizations saved to: {mask_viz_dir}")
    
    return stats

def create_summary_montage():
    """Create a summary montage showing problematic cases"""
    
    print(f"\nCREATING SUMMARY MONTAGE")
    print("="*40)
    
    # This would create a grid showing the most interesting/problematic cases
    # For now, just list the files created
    mask_viz_dir = OUTPUT_DIR / "mask_visualizations"
    
    if mask_viz_dir.exists():
        png_files = list(mask_viz_dir.glob("*.png"))
        print(f"Created {len(png_files)} mask visualization files:")
        
        # Group by subject
        subjects = {}
        for png_file in png_files:
            subject_code = png_file.stem.split('_')[0]
            if subject_code not in subjects:
                subjects[subject_code] = []
            subjects[subject_code].append(png_file.name)
        
        for subject_code, files in subjects.items():
            print(f"  {subject_code}: {len(files)} masks")

# Run comprehensive visualization
print("RUNNING COMPREHENSIVE MASK VISUALIZATION")
print("="*70)

# Execute the main function
visualization_stats = plot_all_masks_on_anatomy()

# Create summary
create_summary_montage()

print("\n🎯 COMPREHENSIVE VISUALIZATION COMPLETE!")
print("Check the 'mask_visualizations' folder for all generated images")
